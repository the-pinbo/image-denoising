# %%
from google.colab import drive

# Montamos nuestra unidad drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from matplotlib import image
from shutil import copyfile
import cv2
import seaborn as sns
import random

import PIL
from PIL import Image
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tqdm import tqdm

# %%
# %tensorflow_version 2.x
from tensorflow.keras import backend as K
import tensorflow as tf

tf.random.set_seed(0)
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
# srcPath = '/content/drive/My Drive/2021-1/TAC/TA/data/BSDS300/images'
#srcPath = 'data/BSDS300/images'
srcPath = '/content/drive/MyDrive/bsd_images/images'

train_scan_paths = os.listdir(srcPath + '/train')
test_scan_paths = os.listdir(srcPath + '/test')

train_scan_paths = [(srcPath + '/train/' + x) for x in train_scan_paths]
test_scan_paths = [(srcPath + '/test/' + x) for x in test_scan_paths]


print("train scan with length of: {}".format(len(train_scan_paths)))
print("test scan with length of: {}".format(len(test_scan_paths)))
# Out:
# train scan with length of: 200
# test scan with length of: 200

# %%
train_scan_paths[:5]
# Out:
# ['/content/drive/MyDrive/bsd_images/images/train/130034.jpg',
#  '/content/drive/MyDrive/bsd_images/images/train/134052.jpg',
#  '/content/drive/MyDrive/bsd_images/images/train/109034.jpg',
#  '/content/drive/MyDrive/bsd_images/images/train/118035.jpg',
#  '/content/drive/MyDrive/bsd_images/images/train/113009.jpg']

# %%
test_scan_paths[:5]
# Out:
# ['/content/drive/MyDrive/bsd_images/images/test/10081.jpg',
#  '/content/drive/MyDrive/bsd_images/images/test/104055.jpg',
#  '/content/drive/MyDrive/bsd_images/images/test/120093.jpg',
#  '/content/drive/MyDrive/bsd_images/images/test/112090.jpg',
#  '/content/drive/MyDrive/bsd_images/images/test/109055.jpg']

# %%
# def normalize_scan(image):

#   norm_image = cv2.normalize(image, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)

#   return norm_image

# def resize_scan(scan, desired_width, desired_height):
  
#   scan = cv2.resize(scan, (desired_height, desired_width))

#   return scan

# def preprocess_scan(path, width, height):
  
#   scan = cv2.cvtColor(cv2.imread(path), cv2.COLOR_BGR2RGB)  
#   resized_scan = resize_scan(scan, width, height)  
#   normalized_resized_scan = normalize_scan(resized_scan)

#   return normalized_resized_scan

# def generate_img(image): 
#   plt.axis("off")
#   plt.imshow(image)
#   plt.show()
  
# def generate_img_2(image): 
#   img = plt.imshow(image)
#   # img.set_cmap('hot')
#   plt.axis('off')
#   # plt.show()
def normalize_scan(image):

  norm_image = cv2.normalize(image, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)

  return norm_image

def resize_scan(scan, desired_width, desired_height):
  
  scan = cv2.resize(scan, (desired_height, desired_width))

  return scan

def preprocess_scan(path, width, height):
  
  scan = cv2.imread(path)  
  resized_scan = resize_scan(scan, width, height)  
  normalized_resized_scan = normalize_scan(resized_scan)

  return normalized_resized_scan

def generate_img(image): 
  plt.axis("off")
  plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
  plt.show()
def generate_img_2(image): 
  img = plt.imshow(image)
  # img.set_cmap('hot')
  plt.axis('off')
  # plt.show()

# %%
width = 256
height = 256

# %%
train_scans = [preprocess_scan(path, width, height) for path in train_scan_paths]
test_scans = [preprocess_scan(path, width, height) for path in test_scan_paths]

# %%
data = train_scans[0]

generate_img(data)
# plt.axis("off")
# plt.imshow(cv2.cvtColor(data, cv2.COLOR_BGR2RGB))
# plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def noisy(noise_typ,image):
  if noise_typ == "gauss":
    row,col,ch= image.shape
    mean = 0
    var = 0.01
    sigma = var**0.5
    gauss = np.random.normal(mean,sigma,(row,col,ch))
    gauss = gauss.reshape(row,col,ch)
    noisy = image + gauss
    return noisy
  
  elif noise_typ == "s&p":
    row,col,ch = image.shape
    s_vs_p = 0.5
    amount = 0.004
    out = np.copy(image)
    # Salt mode
    num_salt = np.ceil(amount * image.size * s_vs_p)
    coords = [np.random.randint(0, i - 1, int(num_salt))
            for i in image.shape]
    out[coords] = 1

    # Pepper mode
    num_pepper = np.ceil(amount* image.size * (1. - s_vs_p))
    coords = [np.random.randint(0, i - 1, int(num_pepper))
            for i in image.shape]
    out[coords] = 0
    return out
  
  elif noise_typ == "poisson":
    vals = len(np.unique(image))
    vals = 2 ** np.ceil(np.log2(vals))
    noisy = np.random.poisson(image * vals) / float(vals)
    return noisy
  
  elif noise_typ =="speckle":
    row,col,ch = image.shape
    gauss = np.random.randn(row,col,ch)
    gauss = gauss.reshape(row,col,ch)        
    noisy = image + image * gauss
    return noisy

    ##Added new
  elif noise_typ == "bernoulli":
    N = 100
    P = 0.5
    bernoulli = np.random.binomial(n = N, p = P, size = image.shape)
    noisy = bernoulli + image
    return noisy

# %%
# N = 100
# P = 0.7
# bernoulli = np.random.binomial(n = N, p = P, size = (img.shape[0], img.shape[1], 3))
# print(bernoulli.shape)
# noisy = img + bernoulli
# fig = plt.figure()
# fig.add_subplot(121)
# plt.imshow(img)
# fig.add_subplot(122)
# plt.imshow(noisy)

# %%
image = train_scans[0]
noisyimg = noisy('gauss', image)
generate_img(noisyimg.astype('float32'))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
train_gaussian_noise_images = np.array([noisy('gauss', x) for x in train_scans])
test_gaussian_noise_images = np.array([noisy('gauss', x) for x in test_scans])

train_target_images = np.array(train_scans)
test_target_images = np.array(test_scans)

# %%
# Funcion de perdida - MSE
from tensorflow.keras.losses import MeanSquaredError

mse = tf.keras.losses.MeanSquaredError()
mse(train_gaussian_noise_images[0], train_scans[0]).numpy()
# Out:
# 0.009989612

# %%
# Batch size
BATCH_SIZE = 10

# Train size
train_gaussian_noise_images.shape
# Out:
# (200, 256, 256, 3)

# %%
from keras import Input, Model, Sequential
from keras import layers
from keras import backend as K
from tensorflow.keras.regularizers import l1
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomContrast, RandomRotation

K.clear_session()

# %%
data_augmentation = Sequential(
    [
     RandomFlip(mode="horizontal",seed=0),
     RandomContrast(0.1,seed=0)     
     ]
)

# %%
def Autoencoder():
  
  input_img = Input(shape=(256, 256, 3))  
  augmentation = data_augmentation(input_img)
  # ============================================================================
  # == ENCODER
  # ============================================================================

  conv_1_a = layers.Conv2D(48, (3, 3), padding='same', use_bias=False)(augmentation)
  l_relu_1_a = layers.LeakyReLU()(conv_1_a)
  conv_1_b = layers.Conv2D(48, (3, 3), padding='same', use_bias=False)(l_relu_1_a)
  l_relu_1_b = layers.LeakyReLU()(conv_1_b)
  maxpool_1 = layers.MaxPooling2D((2, 2), padding='same')(l_relu_1_b)
  #print(maxpool_1.shape)

  conv_2 = layers.Conv2D(48, (3, 3), padding='same', use_bias=False)(maxpool_1)
  l_relu_2 = layers.LeakyReLU()(conv_2)
  maxpool_2 = layers.MaxPooling2D((2, 2), padding='same')(l_relu_2)
  #print(maxpool_2.shape)

  conv_3 = layers.Conv2D(48, (3, 3), padding='same', use_bias=False)(maxpool_2)
  l_relu_3 = layers.LeakyReLU()(conv_3)
  maxpool_3 = layers.MaxPooling2D((2, 2), padding='same')(l_relu_3)
  #print(maxpool_3.shape)

  conv_4 = layers.Conv2D(48, (3, 3), padding='same', use_bias=False)(maxpool_3)
  l_relu_4 = layers.LeakyReLU()(conv_4)
  maxpool_4 = layers.MaxPooling2D((2, 2), padding='same')(l_relu_4)
  #print(maxpool_4.shape)

  conv_5_a = layers.Conv2D(48, (3, 3), padding='same', use_bias=False)(maxpool_4)
  l_relu_5_a = layers.LeakyReLU()(conv_5_a)
  maxpool_5 = layers.MaxPooling2D((2, 2), padding='same')(l_relu_5_a)
  #print(maxpool_5.shape)

  conv_5_b = layers.Conv2D(48, (3, 3), padding='same', use_bias=False)(maxpool_5)
  encoded = layers.LeakyReLU()(conv_5_b)

  # ============================================================================
  # == DECODER
  # ============================================================================

  upsamp_6 = layers.UpSampling2D((2, 2))(encoded)
  #print(upsamp_6.shape)
  concat_6 = tf.concat([upsamp_6, maxpool_4], axis=3)
  #print(concat_6.shape)
  conv_6_a = layers.Conv2D(96, (3, 3), padding='same', use_bias=False)(concat_6)
  l_relu_6_a = layers.LeakyReLU()(conv_6_a)
  conv_6_b = layers.Conv2D(96, (3, 3), padding='same', use_bias=False)(l_relu_6_a)
  l_relu_6_b = layers.LeakyReLU()(conv_6_b)
  
  upsamp_7 = layers.UpSampling2D((2, 2))(l_relu_6_b)
  #print(upsamp_7.shape)
  concat_7 = tf.concat([upsamp_7, maxpool_3], axis=3)
  #print(concat_7.shape)
  conv_7_a = layers.Conv2D(96, (3, 3), padding='same', use_bias=False)(concat_7)
  l_relu_7_a = layers.LeakyReLU()(conv_7_a)
  conv_7_b = layers.Conv2D(96, (3, 3), padding='same', use_bias=False)(l_relu_7_a)
  l_relu_7_b = layers.LeakyReLU()(conv_7_b)

  upsamp_8 = layers.UpSampling2D((2, 2))(l_relu_7_b)
  #print(upsamp_8.shape)
  concat_8 = tf.concat([upsamp_8, maxpool_2], axis=3)
  #print(concat_8.shape)
  conv_8_a = layers.Conv2D(96, (3, 3), padding='same', use_bias=False)(concat_8)
  l_relu_8_a = layers.LeakyReLU()(conv_8_a)
  conv_8_b = layers.Conv2D(96, (3, 3), padding='same', use_bias=False)(l_relu_8_a)
  l_relu_8_b = layers.LeakyReLU()(conv_8_b)

  upsamp_9 = layers.UpSampling2D((2, 2))(l_relu_8_b)
  #print(upsamp_9.shape)
  concat_9 = tf.concat([upsamp_9, maxpool_1], axis=3)
  #print(concat_9.shape)
  conv_9_a = layers.Conv2D(96, (3, 3), padding='same', use_bias=False)(concat_9)
  l_relu_9_a = layers.LeakyReLU()(conv_9_a)
  conv_9_b = layers.Conv2D(96, (3, 3), padding='same', use_bias=False)(l_relu_9_a)
  l_relu_9_b = layers.LeakyReLU()(conv_9_b)

  upsamp_10 = layers.UpSampling2D((2, 2))(l_relu_9_b)
  #print(upsamp_10.shape)
  concat_10 = tf.concat([upsamp_10, input_img], axis=3)
  #print(concat_10.shape)
  conv_10_a = layers.Conv2D(64, (3, 3), padding='same', use_bias=False)(concat_10)
  l_relu_10_a = layers.LeakyReLU()(conv_10_a)
  conv_10_b = layers.Conv2D(32, (3, 3), padding='same', use_bias=False)(l_relu_10_a)
  l_relu_10_b = layers.LeakyReLU()(conv_10_b)

  decoded = layers.Conv2D(3, (3, 3), activation='sigmoid', padding='same')(l_relu_10_b)
  #print(decoded.shape)
  # decoded = layers.Conv2D(3, (3, 3), activation='sigmoid', padding='same')(l_relu_7_b)

  return Model(input_img, decoded)

# %%
autoencoder = Autoencoder()

# %%
# from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, Add
# def REDNet():

#   inp = Input(shape = (256, 256, 3))
#   augmentation = data_augmentation(inp)
#   conv1 = Conv2D(128, (3, 3), padding = 'same', activation = 'relu')(augmentation)
#   conv22 = Conv2D(128, (3, 3), padding = 'same', activation = 'relu')(conv1)
#   conv3 = Conv2D(128, (3, 3), padding = 'same', activation = 'relu')(conv2)
#   conv4 = Conv2D(128, (3, 3), padding = 'same', activation = 'relu')(conv3)
#   conv5 = Conv2D(128, (3, 3), padding = 'same', activation = 'relu')(conv4)  
#   tranconv1 = Conv2DTranspose(128, (3, 3), padding = 'same', activation = 'relu')(conv5)
#   s1 = Add()([tranconv1, l4])
#   tranconv2 = Conv2DTranspose(128, (3, 3), padding = 'same', activation = 'relu')(s1)
#   s2 = Add()([l7, l3])
#   tranconv3 = Conv2DTranspose(128, (3, 3), padding = 'same', activation = 'relu')(s2)
#   s3 = Add()([l8, l2])
#   tranconv4 = Conv2DTranspose(128, (3, 3), padding = 'same', activation = 'relu')(s3)
#   s4 = Add()([l9, l1])
#   op = Conv2DTranspose(3, (3, 3), padding = 'same', activation = 'relu')(s4)
  
#   model = Model(inp, op)
#   return model    
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, Add
def REDNet():

    il = Input(shape = (256, 256, 3))
    augmentation = data_augmentation(il)
    l1 = Conv2D(16, (3, 3), padding = 'same', activation = 'relu', )(augmentation)
    l2 = Conv2D(16, (3, 3), padding = 'same', activation = 'relu')(l1)
    l3 = Conv2D(16, (3, 3), padding = 'same', activation = 'relu')(l2)
    l4 = Conv2D(16, (3, 3), padding = 'same', activation = 'relu')(l3)
    l5 = Conv2D(16, (3, 3), padding = 'same', activation = 'relu')(l4)  
    l6 = Conv2DTranspose(16, (3, 3), padding = 'same', activation = 'relu')(l5)
    s1 = Add()([l6, l4])
    l7 = Conv2DTranspose(16, (3, 3), padding = 'same', activation = 'relu')(s1)
    s2 = Add()([l7, l3])
    l8 = Conv2DTranspose(16, (3, 3), padding = 'same', activation = 'relu')(s2)
    s3 = Add()([l8, l2])
    l9 = Conv2DTranspose(16, (3, 3), padding = 'same', activation = 'relu')(s3)
    s4 = Add()([l9, l1])
    l10 = Conv2DTranspose(3, (3, 3), padding = 'same', activation = 'relu')(s4)
  
    model = Model(il, l10)
    return model

# %%
autoencoder = REDNet()
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2

# %%
from tensorflow.keras.utils import plot_model
plot_model(autoencoder, show_shapes=True, dpi=64)

# %%
autoencoder.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 256, 256, 3)  0           ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 256, 256, 16  448         ['sequential[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 16  2320        ['conv2d[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 16  2320        ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 16  2320        ['conv2d_2[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 16  2320        ['conv2d_3[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 256, 256, 16  2320       ['conv2d_4[0][0]']
#  ose)                           )
#
#  add (Add)                      (None, 256, 256, 16  0           ['conv2d_transpose[0][0]',
#                                 )                                 'conv2d_3[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 256, 256, 16  2320       ['add[0][0]']
#  spose)                         )
#
#  add_1 (Add)                    (None, 256, 256, 16  0           ['conv2d_transpose_1[0][0]',
#                                 )                                 'conv2d_2[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 16  2320       ['add_1[0][0]']
#  spose)                         )
#
#  add_2 (Add)                    (None, 256, 256, 16  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 16  2320       ['add_2[0][0]']
#  spose)                         )
#
#  add_3 (Add)                    (None, 256, 256, 16  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 256, 256, 3)  435        ['add_3[0][0]']
#  spose)
#
# ==================================================================================================
# Total params: 19,443
# Trainable params: 19,443
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# %cd /content/drive/My Drive/TA_02_TAC
# Out:
# [Errno 2] No such file or directory: '/content/drive/My Drive/TA_02_TAC'
# /content

# %%
from tensorflow.keras.optimizers import Adam

# Definimos la funcion de optimizacion
autoencoder_optimizer = Adam(0.0001, beta_1=0.9)

# %%
autoencoder.compile(optimizer='adam', loss=MeanSquaredError(), metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_path = "my_model/model_gauss_10"

monitor = "val_accuracy"

mode = "max"

model_checkpoint = ModelCheckpoint(checkpoint_path, monitor=monitor, verbose=1, save_best_only=True, save_weights_only=True, mode=mode)

# %%
# from tensorflow.keras.preprocessing import ImageDataGenerator

# train_datagen = ImageDataGenerator(rescale = 1/255.)

# train_generator = train_datagen.flow_from_directory()

# %%
EPOCHS = 40
history = autoencoder.fit(train_gaussian_noise_images, train_target_images,
                epochs=EPOCHS,
                shuffle=True,
                validation_data=(test_gaussian_noise_images, test_target_images), callbacks=[model_checkpoint])
# Out:
# Epoch 1/40
# 7/7 [==============================] - ETA: 0s - loss: 0.1295 - accuracy: 0.4059
# Epoch 1: val_accuracy improved from -inf to 0.37287, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 14s 461ms/step - loss: 0.1295 - accuracy: 0.4059 - val_loss: 0.0692 - val_accuracy: 0.3729
# Epoch 2/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.3815
# Epoch 2: val_accuracy did not improve from 0.37287
# 7/7 [==============================] - 2s 328ms/step - loss: 0.0610 - accuracy: 0.3815 - val_loss: 0.0195 - val_accuracy: 0.3663
# Epoch 3/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0409 - accuracy: 0.4754
# Epoch 3: val_accuracy improved from 0.37287 to 0.54214, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 330ms/step - loss: 0.0409 - accuracy: 0.4754 - val_loss: 0.0183 - val_accuracy: 0.5421
# Epoch 4/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 0.5192
# Epoch 4: val_accuracy did not improve from 0.54214
# 7/7 [==============================] - 2s 327ms/step - loss: 0.0368 - accuracy: 0.5192 - val_loss: 0.0141 - val_accuracy: 0.4642
# Epoch 5/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0352 - accuracy: 0.4757
# Epoch 5: val_accuracy improved from 0.54214 to 0.55253, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 332ms/step - loss: 0.0352 - accuracy: 0.4757 - val_loss: 0.0129 - val_accuracy: 0.5525
# Epoch 6/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.5571
# Epoch 6: val_accuracy improved from 0.55253 to 0.60545, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 334ms/step - loss: 0.0317 - accuracy: 0.5571 - val_loss: 0.0120 - val_accuracy: 0.6055
# Epoch 7/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0336 - accuracy: 0.5614
# Epoch 7: val_accuracy improved from 0.60545 to 0.61259, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 334ms/step - loss: 0.0336 - accuracy: 0.5614 - val_loss: 0.0109 - val_accuracy: 0.6126
# Epoch 8/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.5794
# Epoch 8: val_accuracy did not improve from 0.61259
# 7/7 [==============================] - 2s 326ms/step - loss: 0.0329 - accuracy: 0.5794 - val_loss: 0.0117 - val_accuracy: 0.5968
# Epoch 9/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0322 - accuracy: 0.5850
# Epoch 9: val_accuracy improved from 0.61259 to 0.62865, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 335ms/step - loss: 0.0322 - accuracy: 0.5850 - val_loss: 0.0105 - val_accuracy: 0.6287
# Epoch 10/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.5881
# Epoch 10: val_accuracy improved from 0.62865 to 0.63634, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 333ms/step - loss: 0.0329 - accuracy: 0.5881 - val_loss: 0.0104 - val_accuracy: 0.6363
# Epoch 11/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0299 - accuracy: 0.5919
# Epoch 11: val_accuracy did not improve from 0.63634
# 7/7 [==============================] - 2s 328ms/step - loss: 0.0299 - accuracy: 0.5919 - val_loss: 0.0105 - val_accuracy: 0.6182
# Epoch 12/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.5936
# Epoch 12: val_accuracy improved from 0.63634 to 0.64721, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 336ms/step - loss: 0.0295 - accuracy: 0.5936 - val_loss: 0.0092 - val_accuracy: 0.6472
# Epoch 13/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.6046
# Epoch 13: val_accuracy improved from 0.64721 to 0.65308, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 333ms/step - loss: 0.0298 - accuracy: 0.6046 - val_loss: 0.0093 - val_accuracy: 0.6531
# Epoch 14/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0322 - accuracy: 0.6016
# Epoch 14: val_accuracy did not improve from 0.65308
# 7/7 [==============================] - 2s 330ms/step - loss: 0.0322 - accuracy: 0.6016 - val_loss: 0.0104 - val_accuracy: 0.6483
# Epoch 15/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0316 - accuracy: 0.6063
# Epoch 15: val_accuracy did not improve from 0.65308
# 7/7 [==============================] - 2s 329ms/step - loss: 0.0316 - accuracy: 0.6063 - val_loss: 0.0106 - val_accuracy: 0.6463
# Epoch 16/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.6144
# Epoch 16: val_accuracy improved from 0.65308 to 0.66417, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 338ms/step - loss: 0.0284 - accuracy: 0.6144 - val_loss: 0.0105 - val_accuracy: 0.6642
# Epoch 17/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0324 - accuracy: 0.6026
# Epoch 17: val_accuracy did not improve from 0.66417
# 7/7 [==============================] - 2s 330ms/step - loss: 0.0324 - accuracy: 0.6026 - val_loss: 0.0117 - val_accuracy: 0.6466
# Epoch 18/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0272 - accuracy: 0.6230
# Epoch 18: val_accuracy improved from 0.66417 to 0.67533, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 337ms/step - loss: 0.0272 - accuracy: 0.6230 - val_loss: 0.0095 - val_accuracy: 0.6753
# Epoch 19/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0296 - accuracy: 0.6188
# Epoch 19: val_accuracy did not improve from 0.67533
# 7/7 [==============================] - 2s 330ms/step - loss: 0.0296 - accuracy: 0.6188 - val_loss: 0.0095 - val_accuracy: 0.6690
# Epoch 20/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0299 - accuracy: 0.6256
# Epoch 20: val_accuracy improved from 0.67533 to 0.67845, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 336ms/step - loss: 0.0299 - accuracy: 0.6256 - val_loss: 0.0089 - val_accuracy: 0.6784
# Epoch 21/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.6370
# Epoch 21: val_accuracy improved from 0.67845 to 0.68431, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 337ms/step - loss: 0.0285 - accuracy: 0.6370 - val_loss: 0.0084 - val_accuracy: 0.6843
# Epoch 22/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.6390
# Epoch 22: val_accuracy did not improve from 0.68431
# 7/7 [==============================] - 2s 333ms/step - loss: 0.0283 - accuracy: 0.6390 - val_loss: 0.0086 - val_accuracy: 0.6838
# Epoch 23/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.6378
# Epoch 23: val_accuracy improved from 0.68431 to 0.69126, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 339ms/step - loss: 0.0301 - accuracy: 0.6378 - val_loss: 0.0086 - val_accuracy: 0.6913
# Epoch 24/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.6377
# Epoch 24: val_accuracy did not improve from 0.69126
# 7/7 [==============================] - 2s 331ms/step - loss: 0.0285 - accuracy: 0.6377 - val_loss: 0.0090 - val_accuracy: 0.6899
# Epoch 25/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.6507
# Epoch 25: val_accuracy improved from 0.69126 to 0.69235, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 339ms/step - loss: 0.0260 - accuracy: 0.6507 - val_loss: 0.0090 - val_accuracy: 0.6924
# Epoch 26/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0270 - accuracy: 0.6585
# Epoch 26: val_accuracy improved from 0.69235 to 0.70844, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 341ms/step - loss: 0.0270 - accuracy: 0.6585 - val_loss: 0.0069 - val_accuracy: 0.7084
# Epoch 27/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.6589
# Epoch 27: val_accuracy improved from 0.70844 to 0.71148, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 341ms/step - loss: 0.0277 - accuracy: 0.6589 - val_loss: 0.0068 - val_accuracy: 0.7115
# Epoch 28/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.6606
# Epoch 28: val_accuracy did not improve from 0.71148
# 7/7 [==============================] - 2s 335ms/step - loss: 0.0285 - accuracy: 0.6606 - val_loss: 0.0088 - val_accuracy: 0.7029
# Epoch 29/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0304 - accuracy: 0.6483
# Epoch 29: val_accuracy did not improve from 0.71148
# 7/7 [==============================] - 2s 335ms/step - loss: 0.0304 - accuracy: 0.6483 - val_loss: 0.0088 - val_accuracy: 0.7092
# Epoch 30/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.6616
# Epoch 30: val_accuracy improved from 0.71148 to 0.71520, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 341ms/step - loss: 0.0288 - accuracy: 0.6616 - val_loss: 0.0086 - val_accuracy: 0.7152
# Epoch 31/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.6683
# Epoch 31: val_accuracy improved from 0.71520 to 0.71773, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 342ms/step - loss: 0.0267 - accuracy: 0.6683 - val_loss: 0.0079 - val_accuracy: 0.7177
# Epoch 32/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.6758
# Epoch 32: val_accuracy improved from 0.71773 to 0.72224, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 344ms/step - loss: 0.0252 - accuracy: 0.6758 - val_loss: 0.0068 - val_accuracy: 0.7222
# Epoch 33/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.6706
# Epoch 33: val_accuracy did not improve from 0.72224
# 7/7 [==============================] - 2s 338ms/step - loss: 0.0283 - accuracy: 0.6706 - val_loss: 0.0077 - val_accuracy: 0.7196
# Epoch 34/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.6806
# Epoch 34: val_accuracy did not improve from 0.72224
# 7/7 [==============================] - 2s 340ms/step - loss: 0.0247 - accuracy: 0.6806 - val_loss: 0.0075 - val_accuracy: 0.7218
# Epoch 35/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0294 - accuracy: 0.6775
# Epoch 35: val_accuracy improved from 0.72224 to 0.73246, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 345ms/step - loss: 0.0294 - accuracy: 0.6775 - val_loss: 0.0078 - val_accuracy: 0.7325
# Epoch 36/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.6754
# Epoch 36: val_accuracy did not improve from 0.73246
# 7/7 [==============================] - 2s 341ms/step - loss: 0.0274 - accuracy: 0.6754 - val_loss: 0.0077 - val_accuracy: 0.7239
# Epoch 37/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0302 - accuracy: 0.6728
# Epoch 37: val_accuracy did not improve from 0.73246
# 7/7 [==============================] - 2s 343ms/step - loss: 0.0302 - accuracy: 0.6728 - val_loss: 0.0088 - val_accuracy: 0.7314
# Epoch 38/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.6879
# Epoch 38: val_accuracy did not improve from 0.73246
# 7/7 [==============================] - 2s 340ms/step - loss: 0.0264 - accuracy: 0.6879 - val_loss: 0.0079 - val_accuracy: 0.7258
# Epoch 39/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0294 - accuracy: 0.6837
# Epoch 39: val_accuracy improved from 0.73246 to 0.73721, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 345ms/step - loss: 0.0294 - accuracy: 0.6837 - val_loss: 0.0074 - val_accuracy: 0.7372
# Epoch 40/40
# 7/7 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.6760
# Epoch 40: val_accuracy improved from 0.73721 to 0.74023, saving model to my_model/model_gauss_10
# 7/7 [==============================] - 2s 344ms/step - loss: 0.0259 - accuracy: 0.6760 - val_loss: 0.0073 - val_accuracy: 0.7402

# %%
def show_results(log):
  val_loss = log.history['val_loss']
  val_acc = log.history['val_accuracy']
      
  fig, axes = plt.subplots(1, 2, figsize=(14,4))
  ax1, ax2 = axes
  ax1.plot(log.history['loss'], label='train')
  ax1.plot(val_loss, label='test')
  ax1.set_xlabel('epoch'); ax1.set_ylabel('loss')
  ax2.plot(log.history['accuracy'], label='train')
  ax2.plot(val_acc, label='test')
  ax2.set_xlabel('epoch'); ax2.set_ylabel('accuracy')
  for ax in axes: ax.legend()

# %%
show_results(history)

# %%
def generate_images(model, test_input, tar):
  prediction = model.predict(test_input.reshape(-1,256,256,3))
  plt.figure(figsize=(15, 15))

  display_list = [test_input.astype('float32'), tar.astype('float32'), prediction.reshape(256,256,3)]
  title = ['Input Image', 'Ground Truth', 'Predicted Image']

  for i in range(3):
    plt.subplot(1, 3, i+1)
    plt.title(title[i])

    plt.axis("off")
    plt.imshow(cv2.cvtColor(display_list[i], cv2.COLOR_BGR2RGB))
    # img = plt.imshow(tf.cast((display_list[i] * 255),np.uint8))
    # # img.set_cmap('hot')
    # plt.axis('off')
    # print("OK 3")
    # plt.imshow(display_list[i])
    # plt.axis('off')

  plt.show()

# %%
## Visualizamos algunas prediccinoes
for inp, tar in zip(test_gaussian_noise_images[:5], test_target_images[:5]):
  generate_images(autoencoder, inp, tar)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from math import log10, sqrt

def PSNR(original, compressed):
    mse = np.mean((original - compressed) ** 2)
    if(mse == 0):
        return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse))
    return psnr

def plot_comparison(input_image, target_image, prediction):
    plt.figure(figsize=(15, 15))

    display_list = [input_image.astype('float32'), target_image.astype('float32'), prediction.astype('float32')]
    title = ['Input Image', 'Ground Truth', 'Predicted Image']

    for i in range(3):
      plt.subplot(1, 3, i+1)
      plt.title(title[i])
      plt.axis("off")
      plt.imshow(cv2.cvtColor(display_list[i], cv2.COLOR_BGR2RGB))
    plt.show()

# %%
# Realizamos predicciones a las imagenes de testing y obtenemos el PSNR
list_test_predictions = []
list_PSNR = []
for inp, tar in zip(test_gaussian_noise_images, test_target_images):
    prediction = autoencoder.predict(inp.reshape(-1,256,256,3))
    prediction = prediction.reshape(256,256,3)
    list_test_predictions.append(prediction)
    list_PSNR.append(PSNR(tar, prediction))

# %%
np.array([100 - x for x in list_PSNR]).mean()
# Out:
# 30.259653733162992

# %%
# TOP 5 RESULTADOS
for index in np.array(list_PSNR).argsort()[-5:]:
  plot_comparison(test_gaussian_noise_images[index], test_target_images[index],list_test_predictions[index])
# Out:
# Output hidden; open in https://colab.research.google.com to view.
